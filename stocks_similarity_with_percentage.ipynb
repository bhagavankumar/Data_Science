# %%
import pandas as pd
import numpy as np
stocks=pd.read_csv("TSX 60.csv")

# %%
stocks.head()
# Out:
#                                STOCKS  1-Jul-24  13-Jul-24  27-Jul-24  \
# 0                           TSX INDEX   1304.80    1351.31    1362.71
# 1                   Barrick Gold Corp     22.82      25.05      24.61
# 2              Agnico Eagle Mines Ltd     89.48     102.40     101.54
# 3  Algonquin Power and Utilities Corp      8.04       8.58       8.58
# 4       Alimentation Couche-Tard Inc.     76.77      81.49      82.62
#
#    3-Aug-24  10-Aug-24  17-Aug-24  24-Aug-24  31-Aug-24  8-Sep-24  15-Sep-24  \
# 0   1329.97    1339.25    1381.96    1394.46    1401.13   1373.45    1415.97
# 1     24.82      23.91      26.99      27.71      27.21     25.79      28.31
# 2    104.14     101.86     109.54     111.84     109.80    104.31     113.07
# 3      8.54       7.42       7.32       7.26       7.31      7.08       7.48
# 4     81.76      79.89      83.57      78.27      76.93     76.86      75.00
#
#    22-Sep-24  29-Sep-24  6-Oct-24  13-Oct-24  20-Oct-24  27-Oct-24  3-Nov-24  \
# ...

# %%
stocks.drop(stocks.columns[stocks.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
stocks.dropna(subset=['STOCKS'], how='all', inplace=True)

# %%
def percentage_change(col1,col2):
    return ((col2 - col1) / col1) * 100

# %%
stocks['a'] = percentage_change(stocks['1-Jul-24'], stocks['13-Jul-24'])    
stocks['b'] =  percentage_change(stocks['13-Jul-24'], stocks['27-Jul-24'])
stocks['c'] =  percentage_change(stocks['27-Jul-24'], stocks['3-Aug-24'])
stocks['d'] =  percentage_change(stocks['3-Aug-24'], stocks['10-Aug-24'])
stocks['e'] =  percentage_change(stocks['10-Aug-24'], stocks['17-Aug-24'])
stocks['f'] =  percentage_change(stocks['17-Aug-24'], stocks['24-Aug-24'])
stocks['g'] =  percentage_change(stocks['24-Aug-24'], stocks['31-Aug-24'])
stocks['h'] =  percentage_change(stocks['31-Aug-24'], stocks['8-Sep-24'])
stocks['i'] =  percentage_change(stocks['8-Sep-24'], stocks['15-Sep-24'])
stocks['j'] =  percentage_change(stocks['15-Sep-24'], stocks['22-Sep-24'])
stocks['k'] =  percentage_change(stocks['22-Sep-24'], stocks['29-Sep-24'])
stocks['l'] =  percentage_change(stocks['29-Sep-24'], stocks['6-Oct-24'])
stocks['m'] =  percentage_change(stocks['6-Oct-24'], stocks['13-Oct-24'])
stocks['n'] =  percentage_change(stocks['13-Oct-24'], stocks['20-Oct-24'])
stocks['o'] =  percentage_change(stocks['20-Oct-24'], stocks['27-Oct-24'])
stocks['p'] =  percentage_change(stocks['27-Oct-24'], stocks['3-Nov-24'])
stocks['q'] =  percentage_change(stocks['3-Nov-24'], stocks['10-Nov-24'])
stocks['r'] =  percentage_change(stocks['10-Nov-24'], stocks['17-Nov-24'])
stocks.head()
# Out:
#                                STOCKS  1-Jul-24  13-Jul-24  27-Jul-24  \
# 0                           TSX INDEX   1304.80    1351.31    1362.71
# 1                   Barrick Gold Corp     22.82      25.05      24.61
# 2              Agnico Eagle Mines Ltd     89.48     102.40     101.54
# 3  Algonquin Power and Utilities Corp      8.04       8.58       8.58
# 4       Alimentation Couche-Tard Inc.     76.77      81.49      82.62
#
#    3-Aug-24  10-Aug-24  17-Aug-24  24-Aug-24  31-Aug-24  8-Sep-24  ...  \
# 0   1329.97    1339.25    1381.96    1394.46    1401.13   1373.45  ...
# 1     24.82      23.91      26.99      27.71      27.21     25.79  ...
# 2    104.14     101.86     109.54     111.84     109.80    104.31  ...
# 3      8.54       7.42       7.32       7.26       7.31      7.08  ...
# 4     81.76      79.89      83.57      78.27      76.93     76.86  ...
#
#           i         j         k         l         m         n         o  \
# ...

# %%
stocks.drop(['STOCKS'],axis=1,inplace=True)

# %%
stocks.drop(['1-Jul-24'],axis=1,inplace=True)
stocks.drop(['13-Jul-24'],axis=1,inplace=True)
stocks.drop(['27-Jul-24'],axis=1,inplace=True)
stocks.drop(['3-Aug-24'],axis=1,inplace=True)
stocks.drop(['10-Aug-24'],axis=1,inplace=True)
stocks.drop(['17-Aug-24'],axis=1,inplace=True)
stocks.drop(['24-Aug-24'],axis=1,inplace=True)
stocks.drop(['31-Aug-24'],axis=1,inplace=True)
stocks.drop(['8-Sep-24'],axis=1,inplace=True)
stocks.drop(['15-Sep-24'],axis=1,inplace=True)
stocks.drop(['22-Sep-24'],axis=1,inplace=True)
stocks.drop(['29-Sep-24'],axis=1,inplace=True)
stocks.drop(['6-Oct-24'],axis=1,inplace=True)
stocks.drop(['13-Oct-24'],axis=1,inplace=True)
stocks.drop(['20-Oct-24'],axis=1,inplace=True)
stocks.drop(['27-Oct-24'],axis=1,inplace=True)
stocks.drop(['3-Nov-24'],axis=1,inplace=True)
stocks.drop(['10-Nov-24'],axis=1,inplace=True)
stocks.drop(['17-Nov-24'],axis=1,inplace=True)

# %%
stocks.head()
# Out:
#            a         b         c          d          e         f         g  \
# 0   3.564531  0.843626 -2.402565   0.697760   3.189098  0.904512  0.478321
# 1   9.772130 -1.756487  0.853312  -3.666398  12.881639  2.667655 -1.804403
# 2  14.438981 -0.839844  2.560567  -2.189360   7.539760  2.099690 -1.824034
# 3   6.716418  0.000000 -0.466200 -13.114754  -1.347709 -0.819672  0.688705
# 4   6.148235  1.386673 -1.040910  -2.287182   4.606334 -6.341989 -1.712022
#
#           h         i         j         k         l         m         n  \
# 0 -1.975548  3.095854  1.127849  0.312164  0.659283  1.276040  1.483272
# 1 -5.218670  9.771229 -2.437301 -0.941347 -0.328947  0.806747  5.056384
# 2 -5.000000  8.398044 -0.309543 -1.854152 -3.308325  2.206226  8.853928
# 3 -3.146375  5.649718  0.802139 -1.061008 -4.289544 -3.501401  3.628447
# 4 -0.090992 -2.419984  1.453333 -1.011960 -1.805629 -2.285019  2.020202
#
#           o         p         q         r
# ...

# %%
def get_item_recommendations(interaction,itemname):
    otherrows=[rowname for rowname in interaction.index if rowname!=itemname]
    otheritems=interaction.loc[otherrows,:]
    theitem=list(interaction.loc[itemname,:])
    similarities=[]
    for items in otheritems.index:
        similarities.append(cosine_similarity(theitem,list(otheritems.loc[items,:])))
    otheritems['similarities']=similarities
    return list(otheritems.sort_values(by='similarities',ascending=False).index)

# %%
def dot_product(vector1,vector2):
    thedotproduct=np.sum([vector1[k]*vector2[k] for k in range(0,len(vector1))])
    return(thedotproduct)
def vector_norm(vector):
    thenorm=np.sqrt(dot_product(vector,vector))
    return(thenorm)

# %%
def cosine_similarity(vector1,vector2):
    thedotproduct=dot_product(vector1,vector2)
    thecosine=thedotproduct/(vector_norm(vector1)*vector_norm(vector2))
    return(thecosine)

# %%
stocks.head()
# Out:
#            a         b         c          d          e         f         g  \
# 0   3.564531  0.843626 -2.402565   0.697760   3.189098  0.904512  0.478321
# 1   9.772130 -1.756487  0.853312  -3.666398  12.881639  2.667655 -1.804403
# 2  14.438981 -0.839844  2.560567  -2.189360   7.539760  2.099690 -1.824034
# 3   6.716418  0.000000 -0.466200 -13.114754  -1.347709 -0.819672  0.688705
# 4   6.148235  1.386673 -1.040910  -2.287182   4.606334 -6.341989 -1.712022
#
#           h         i         j         k         l         m         n  \
# 0 -1.975548  3.095854  1.127849  0.312164  0.659283  1.276040  1.483272
# 1 -5.218670  9.771229 -2.437301 -0.941347 -0.328947  0.806747  5.056384
# 2 -5.000000  8.398044 -0.309543 -1.854152 -3.308325  2.206226  8.853928
# 3 -3.146375  5.649718  0.802139 -1.061008 -4.289544 -3.501401  3.628447
# 4 -0.090992 -2.419984  1.453333 -1.011960 -1.805629 -2.285019  2.020202
#
#           o         p         q         r
# ...

# %%
get_item_recommendations(stocks,4)[0:10]
# Out:
# [38, 58, 37, 49, 35, 32, 0, 28, 9, 52]

# %%
def get_similar_users(interaction,username):
    othercolumns=[columnname for columnname in interaction.columns if columnname!=username]
    otherusers=interaction[othercolumns]
    theuser=list(interaction[username])
    similarities=[]
    for users in otherusers.columns:
        similarities.append(cosine_similarity(theuser,list(otherusers.loc[:,users])))
    otherusers.loc['similarities',:]=similarities
    return list(otherusers.sort_values(by='similarities',axis=1,ascending=False).columns)

# %%
def get_user_recommendations(interaction,username):
    similar_users=get_similar_users(interaction,username)
    purchase_history=interaction[similar_users[0]]
    purchased=list(purchase_history.loc[purchase_history==1].index)
    purchased2=list(interaction.loc[interaction[username]==1,:].index)
    recs=sorted(list(set(purchased)-set(purchased2)))
    return(recs)

# %%
print(get_user_recommendations(stocks,"e")[0:3])
# Out:
# []
# <ipython-input-77-a6e1564abba5>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   otherusers.loc['similarities',:]=similarities

# %%
def popularity_based(interaction):
    interaction_withcounts=interaction.copy()
    interaction_withcounts.loc[:,'counts']=interaction_withcounts.sum(axis=1)
    sorted=interaction_withcounts.sort_values(by="counts",ascending=False)
    most_popular=list(sorted.index)
    return(most_popular)

# %%
print(popularity_based(stocks))
# Out:
# [48, 5, 9, 15, 56, 30, 7, 49, 36, 27, 2, 39, 11, 24, 10, 42, 22, 34, 14, 59, 46, 28, 32, 43, 58, 8, 35, 0, 38, 33, 19, 20, 31, 60, 23, 29, 50, 37, 57, 13, 52, 1, 4, 25, 51, 54, 12, 41, 26, 45, 44, 55, 53, 18, 16, 17, 40, 6, 47, 3, 21]

# %%
get_item_recommendations(stocks,3)[0:10]
# Out:
# [7, 37, 59, 26, 9, 29, 23, 18, 2, 34]

# %%
item1=list(stocks.loc[1,:])
item2=list(stocks.loc[3,:])
print(cosine_similarity(item1,item2))
# Out:
# 0.4453635235887714

# %%
get_item_recommendations(stocks,23)[0:10]
# Out:
# [31, 28, 7, 56, 12, 45, 29, 32, 3, 59]

# %%
get_item_recommendations(stocks,1)[0:10]
# Out:
# [2, 59, 34, 7, 60, 26, 22, 53, 29, 0]

# %%
stocks.head()
# Out:
#            a         b         c          d          e         f         g  \
# 0   3.564531  0.843626 -2.402565   0.697760   3.189098  0.904512  0.478321
# 1   9.772130 -1.756487  0.853312  -3.666398  12.881639  2.667655 -1.804403
# 2  14.438981 -0.839844  2.560567  -2.189360   7.539760  2.099690 -1.824034
# 3   6.716418  0.000000 -0.466200 -13.114754  -1.347709 -0.819672  0.688705
# 4   6.148235  1.386673 -1.040910  -2.287182   4.606334 -6.341989 -1.712022
#
#           h         i         j         k         l         m         n  \
# 0 -1.975548  3.095854  1.127849  0.312164  0.659283  1.276040  1.483272
# 1 -5.218670  9.771229 -2.437301 -0.941347 -0.328947  0.806747  5.056384
# 2 -5.000000  8.398044 -0.309543 -1.854152 -3.308325  2.206226  8.853928
# 3 -3.146375  5.649718  0.802139 -1.061008 -4.289544 -3.501401  3.628447
# 4 -0.090992 -2.419984  1.453333 -1.011960 -1.805629 -2.285019  2.020202
#
#           o         p         q         r
# ...

# %%
stocks.tail()
# Out:
#             a         b         c         d         e         f         g  \
# 56   2.526032  9.159300  2.153687  0.286726  2.186344  0.213957  2.512728
# 57   2.503854 -1.198992  2.353038 -0.478277  0.500767  1.193442 -0.202518
# 58   5.945424  2.398197 -1.527004 -1.455549  4.691799  1.258703 -0.195793
# 59  13.216228 -0.677256 -0.855443 -4.151557  5.440313  3.823311 -0.738887
# 60   3.633291  3.614622 -3.991257 -3.474183  4.759658  2.026297 -0.847383
#
#            h         i         j         k         l         m         n  \
# 56  1.473887 -0.110515 -0.979927  0.845970 -3.102248  2.597190  5.747492
# 57 -1.436416  1.889306 -3.720433 -1.337449 -0.095933  4.208417  1.013622
# 58  1.081254  1.922730 -2.785404  2.564570 -2.469355  1.316029  0.391029
# 59 -5.582903  8.100203 -0.188213 -0.471420 -3.031380  2.051533  9.859998
# 60 -0.801211  4.334560  0.941854  1.261131  0.824673  3.981138  0.529759
#
#            o         p         q         r
# ...

# %%
#Most similar items to the index
get_item_recommendations(stocks,0)[0:10]
# Out:
# [9, 39, 7, 19, 37, 36, 8, 49, 42, 22]
